# %%
from wikifin_rag.ingest import load_wikifin_data, build_text_index

# %%
chunks = load_wikifin_data()

# %%
print(f"Loaded {len(chunks)} documents")
# Out:
# Loaded 6686 documents

# %%
index = build_text_index(chunks)

# %%
results = index.search("hoe zich beschermen tegen fraude?", num_results=5)

# %%
index.close()
